# %%
import mne
import os
from mne.io import read_raw_fif
import numpy as np
import matplotlib.pyplot as plt
from hytools.vtc_utils import *
from hytools.meg_utils import get_ch_pos
from autoreject import AutoReject
from scipy.io import loadmat, savemat
from brainpipe import feature
# %matplotlib notebook

# %%
find_preprocfile('11', 2, os.listdir(PREPROC_PATH))
# Out:
# 'SA11_2_preproc_raw.fif.gz'

# %%
def find_logfile(subj, bloc, log_files):
    ### Find the right logfile for a specific subject and bloc in a list of log_files
    # (typically the list of files in the log folder, obtained by "os.listdir(LOGS_DIR)")
    for file in log_files:
        if file[7:9] ==  subj and file[10] == bloc:
            break
    return file

def find_preprocfile(subj, bloc, log_files):
    ### Find the right logfile for a specific subject and bloc in a list of log_files
    # (typically the list of files in the log folder, obtained by "os.listdir(LOGS_DIR)")
    for file in log_files:
        if file[2:4] ==  subj and file[5] == str(int(bloc)):
            break
    return file


def split_events_by_VTC(INzone, OUTzone, events):
    INevents = []
    OUTevents = []
    counter = 0
    for i, event in enumerate(events):
        if event[2] == 21:
            try:
                if events[i+1][2] == 99:
                    if counter in INzone:
                        INevents.append(event)
                    if counter in OUTzone:
                        OUTevents.append(event)
            except:
                print('last event')
        elif event[2] == 31:
            try:
                if events[i+1][2] != 99:
                    if counter in INzone:
                        INevents.append(event)
                    if counter in OUTzone:
                        OUTevents.append(event)
            except:
                print('last event')
        counter += 1
    INevents = np.asarray(INevents)
    OUTevents = np.asarray(OUTevents)
    return INevents, OUTevents

def split_events_by_VTC_alltrials(INzone, OUTzone, events):
    ### keeps all trials, miss included
    INevents = []
    OUTevents = []
    counter = 0
    for i, event in enumerate(events):
        if event[2] == 21:
            try:
                if counter in INzone:
                    INevents.append(event)
                if counter in OUTzone:
                    OUTevents.append(event)
            except:
                print('last event')
        elif event[2] == 31:
            try:
                if counter in INzone:
                    INevents.append(event)
                if counter in OUTzone:
                    OUTevents.append(event)
            except:
                print('last event')
        counter += 1
    INevents = np.asarray(INevents)
    OUTevents = np.asarray(OUTevents)
    return INevents, OUTevents

def compute_PSD(epochs, sf, epochs_length, f=None):
    if f == None:
        f = [ [4, 8], [8, 12], [12, 20], [20, 30], [30, 60], [60, 90], [90, 120] ]
    # Choose MEG channels
    data = epochs.get_data() # On sort les data de l'objet MNE pour les avoir dans une matrice (un numpy array pour être précis)
    data = data.swapaxes(0,1).swapaxes(1,2) # On réarange l'ordre des dimensions pour que ça correspond à ce qui est requis par Brainpipe
    objet_PSD = feature.power(sf=int(sf), npts=int(sf*epochs_length), width=int((sf*epochs_length)/2), step=int((sf*epochs_length)/4), f=f, method='hilbert1') # La fonction Brainpipe pour créer un objet de calcul des PSD
    data = data[:,0:960,:] # weird trick pour corriger un pb de segmentation jpense
    #print(data.shape)
    psds = objet_PSD.get(data)[0] # Ici on calcule la PSD !
    return psds

def array_topoplot(toplot, ch_xy, showtitle=False, titles=None, savefig=False, figpath=None, vmin=-1, vmax=1):
    #create fig
    fig, ax = plt.subplots(1,len(toplot), figsize=(20,10))
    for i, data in enumerate(toplot):
        image,_ = mne.viz.plot_topomap(data=data, pos=ch_xy, cmap='magma', vmin=vmin, vmax=vmax, axes=ax[i], show=False)
        #option for title
        if showtitle == True:
            ax[i].set_title(titles[i], fontdict={'fontsize': 20, 'fontweight': 'heavy'})
    #add a colorbar at the end of the line (weird trick from https://www.martinos.org/mne/stable/auto_tutorials/stats-sensor-space/plot_stats_spatio_temporal_cluster_sensors.html#sphx-glr-auto-tutorials-stats-sensor-space-plot-stats-spatio-temporal-cluster-sensors-py)
    from mpl_toolkits.axes_grid1 import make_axes_locatable
    divider = make_axes_locatable(ax[-1])
    ax_colorbar = divider.append_axes('right', size='5%', pad=0.05)
    plt.colorbar(image, cax=ax_colorbar)
    ax_colorbar.tick_params(labelsize=14)
    #save plot if specified
    if savefig == True:
        plt.savefig(figpath, dpi=300)
    plt.show()

# %%
folderpath = '/storage/Yann/saflow_DATA/'
PREPROC_PATH = folderpath + 'saflow_preproc/'
LOGS_DIR = "/home/karim/pCloudDrive/science/saflow/gradCPT/gradCPT_share_Mac_PC/gradCPT_share_Mac_PC/saflow_data/"
IMG_DIR = '/home/karim/pCloudDrive/science/saflow/images/'
EPOCHS_DIR = folderpath + 'saflow_epoched/'
PSDS_DIR = folderpath + 'saflow_PSD/'

FREQS = [ [4, 8], [8, 12], [12, 20], [20, 30], [30, 60], [60, 90], [90, 120] ]
FREQS_NAMES = ['theta', 'alpha', 'lobeta', 'hibeta', 'gamma1', 'gamma2', 'gamma3']

subj_list = ['04', '05', '06', '07', '08', '09', '10', '11', '12', '13']
blocs_list = ['1','2','3', '4', '5', '6']

# %%
# Test debug NO ar
### Also : Freq VS Rare epochs

for subj in subj_list:
    for bloc in blocs_list:
        ## Open file
        preproc_file = find_preprocfile(subj, bloc, os.listdir(PREPROC_PATH))
        print(preproc_file)
        raw = read_raw_fif(PREPROC_PATH + preproc_file, preload=True)
        picks = mne.pick_types(raw.info, meg=True, ref_meg=False, eeg=False, eog=False, stim=False)
        
        ## segmentation
        events = mne.find_events(raw)
        event_id = {'Freq': 21, 'Rare': 31}
        baseline = (None, 0.0)
        reject = {'mag': 4e-12}
        tmin, tmax = 0, 0.8
        epochs = mne.Epochs(raw, events=events, event_id=event_id, tmin=tmin,
                            tmax=tmax, baseline=baseline, reject=None, picks=picks, preload=True)
        psds = compute_PSD(epochs, epochs.info['sfreq'], epochs_length = 0.8)
        psds = np.mean(psds, axis=2)
        print(psds.shape)
        0/0

# %%
##### OPEN PREPROC FILES AND SEGMENT THEM

for subj in subj_list:
    for bloc in blocs_list:
        ### Find logfile to extract VTC
        log_file = find_logfile(subj,bloc,os.listdir(LOGS_DIR))
        VTC, INbounds, OUTbounds, INzone, OUTzone = get_VTC_from_file(LOGS_DIR + log_file, lobound=None, hibound=None)
        ### Load pre-processed datafile
        preproc_file = find_preprocfile(subj, bloc, os.listdir(PREPROC_PATH))
        raw = read_raw_fif(PREPROC_PATH + preproc_file, preload=True)
        picks = mne.pick_types(raw.info, meg=True, ref_meg=False, eeg=False, eog=False, stim=False)

        ### Set some constants for epoching

        baseline = (None, 0.0)
        reject = {'mag': 4e-12}
        tmin, tmax = 0, 0.8

        ### Find events, split them by IN/OUT and start epoching
        events = mne.find_events(raw, min_duration=2/raw.info['sfreq'])
        INevents, OUTevents = split_events_by_VTC(INzone, OUTzone, events)
        try:
            event_id = {'Freq': 21, 'Rare': 31}
            INepochs = mne.Epochs(raw, events=INevents, event_id=event_id, tmin=tmin,
                            tmax=tmax, baseline=baseline, reject=None, picks=picks, preload=True)
        except:
            event_id = {'Freq': 21}
            INepochs = mne.Epochs(raw, events=INevents, event_id=event_id, tmin=tmin,
                            tmax=tmax, baseline=baseline, reject=None, picks=picks, preload=True)
            
        try:
            event_id = {'Freq': 21, 'Rare': 31}
            OUTepochs = mne.Epochs(raw, events=OUTevents, event_id=event_id, tmin=tmin,
                            tmax=tmax, baseline=baseline, reject=None, picks=picks, preload=True)
        except:
            event_id = {'Freq': 21}
            OUTepochs = mne.Epochs(raw, events=OUTevents, event_id=event_id, tmin=tmin,
                            tmax=tmax, baseline=baseline, reject=None, picks=picks, preload=True)
            

        ### Autoreject detects, rejects and interpolate artifacted epochs
        ar = AutoReject()
        INepochs_clean = ar.fit_transform(INepochs)
        OUTepochs_clean = ar.fit_transform(OUTepochs)
        
        INepochs_clean.save(EPOCHS_DIR + 'SA' + subj + '_' + bloc + '_IN_epo.fif.gz')
        OUTepochs_clean.save(EPOCHS_DIR + 'SA' + subj + '_' + bloc + '_OUT_epo.fif.gz')
# Out:
# Opening raw data file /storage/Yann/saflow_DATA/saflow_preproc/SA04_1_preproc_raw.fif.gz...
# /home/karim/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
#     Read 5 compensation matrices
#     Range : 0 ... 587999 =      0.000 ...   489.999 secs
# Ready.
# Current compensation grade : 3
# Reading 0 ... 587999  =      0.000 ...   489.999 secs...
# Trigger channel has a non-zero initial value of 10 (consider using initial_event=True to detect this event)
# Removing orphaned offset at the beginning of the file.
# 1603 events found
# Event IDs: [21 31 99]
# 108 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 108 events and 961 original time points ...
# 0 bad epochs dropped
# 106 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 106 events and 961 original time points ...
# 0 bad epochs dropped
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs |
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs |
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs |
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs |
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.50 and n_interpolate=32
#
# [........................................] 100.00% Repairing epochs |   No bad epochs were found for your data. Returning a copy of the data you wanted to clean. Interpolation may have been done.
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs -
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs -
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs -
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs -
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.50 and n_interpolate=32
#
# [........................................] 100.00% Repairing epochs -   No bad epochs were found for your data. Returning a copy of the data you wanted to clean. Interpolation may have been done.
# Opening raw data file /storage/Yann/saflow_DATA/saflow_preproc/SA04_2_preproc_raw.fif.gz...
# /home/karim/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
#     Read 5 compensation matrices
#     Range : 0 ... 587999 =      0.000 ...   489.999 secs
# Ready.
# Current compensation grade : 3
# Reading 0 ... 587999  =      0.000 ...   489.999 secs...
# Trigger channel has a non-zero initial value of 10 (consider using initial_event=True to detect this event)
# Removing orphaned offset at the beginning of the file.
# 1620 events found
# Event IDs: [21 31 99]
# 96 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 96 events and 961 original time points ...
# 0 bad epochs dropped
# 103 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 103 events and 961 original time points ...
# 0 bad epochs dropped
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs |
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs |
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs |
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs |
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.50 and n_interpolate=1
#
# [........................................] 100.00% Repairing epochs |   No bad epochs were found for your data. Returning a copy of the data you wanted to clean. Interpolation may have been done.
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs \
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs \
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs \
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs \
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.70 and n_interpolate=32
#
# [........................................] 100.00% Repairing epochs \   No bad epochs were found for your data. Returning a copy of the data you wanted to clean. Interpolation may have been done.
# Opening raw data file /storage/Yann/saflow_DATA/saflow_preproc/SA04_3_preproc_raw.fif.gz...
# /home/karim/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
#     Read 5 compensation matrices
#     Range : 0 ... 587999 =      0.000 ...   489.999 secs
# Ready.
# Current compensation grade : 3
# Reading 0 ... 587999  =      0.000 ...   489.999 secs...
# Trigger channel has a non-zero initial value of 10 (consider using initial_event=True to detect this event)
# Removing orphaned offset at the beginning of the file.
# 1479 events found
# Event IDs: [21 31 99]
# last event
# 106 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 106 events and 961 original time points ...
# 0 bad epochs dropped
# 109 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 109 events and 961 original time points ...
# 0 bad epochs dropped
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs -
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs -
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs -
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs -
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.50 and n_interpolate=1
#
# [........................................] 100.00% Repairing epochs -   No bad epochs were found for your data. Returning a copy of the data you wanted to clean. Interpolation may have been done.
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs /
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs /
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs /
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs /
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.60 and n_interpolate=32
#
# [........................................] 100.00% Repairing epochs /   No bad epochs were found for your data. Returning a copy of the data you wanted to clean. Interpolation may have been done.
# Opening raw data file /storage/Yann/saflow_DATA/saflow_preproc/SA04_4_preproc_raw.fif.gz...
# /home/karim/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
#     Read 5 compensation matrices
#     Range : 0 ... 587999 =      0.000 ...   489.999 secs
# Ready.
# Current compensation grade : 3
# Reading 0 ... 587999  =      0.000 ...   489.999 secs...
# Trigger channel has a non-zero initial value of 10 (consider using initial_event=True to detect this event)
# Removing orphaned offset at the beginning of the file.
# 1452 events found
# Event IDs: [21 31 99]
# 108 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 108 events and 961 original time points ...
# 0 bad epochs dropped
# 105 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 105 events and 961 original time points ...
# 0 bad epochs dropped
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs |
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs |
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs |
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs |
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.90 and n_interpolate=4
#
# [........................................] 100.00% Repairing epochs |   No bad epochs were found for your data. Returning a copy of the data you wanted to clean. Interpolation may have been done.
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs /
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs /
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs /
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs /
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.50 and n_interpolate=4
#
# [........................................] 100.00% Repairing epochs /   Dropped 8 epochs
# Opening raw data file /storage/Yann/saflow_DATA/saflow_preproc/SA04_5_preproc_raw.fif.gz...
# /home/karim/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
#     Read 5 compensation matrices
#     Range : 0 ... 587999 =      0.000 ...   489.999 secs
# Ready.
# Current compensation grade : 3
# Reading 0 ... 587999  =      0.000 ...   489.999 secs...
# Trigger channel has a non-zero initial value of 10 (consider using initial_event=True to detect this event)
# Removing orphaned offset at the beginning of the file.
# 1431 events found
# Event IDs: [21 31 99]
# 116 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 116 events and 961 original time points ...
# 0 bad epochs dropped
# 121 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 121 events and 961 original time points ...
# 0 bad epochs dropped
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs |
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs |
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs |
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs |
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.60 and n_interpolate=1
#
# [........................................] 100.00% Repairing epochs |   Dropped 6 epochs
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs /
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs /
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs /
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs /
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.80 and n_interpolate=32
#
# [........................................] 100.00% Repairing epochs /   No bad epochs were found for your data. Returning a copy of the data you wanted to clean. Interpolation may have been done.
# Opening raw data file /storage/Yann/saflow_DATA/saflow_preproc/SA04_6_preproc_raw.fif.gz...
# /home/karim/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
#     Read 5 compensation matrices
#     Range : 0 ... 587999 =      0.000 ...   489.999 secs
# Ready.
# Current compensation grade : 3
# Reading 0 ... 587999  =      0.000 ...   489.999 secs...
# Trigger channel has a non-zero initial value of 10 (consider using initial_event=True to detect this event)
# Removing orphaned offset at the beginning of the file.
# 1443 events found
# Event IDs: [21 31 99]
# 100 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 100 events and 961 original time points ...
# 0 bad epochs dropped
# 101 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 101 events and 961 original time points ...
# 0 bad epochs dropped
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs |
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs |
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs |
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs |
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.50 and n_interpolate=32
#
# [........................................] 100.00% Repairing epochs |   Dropped 2 epochs
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs /
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs /
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs /
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs /
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.50 and n_interpolate=4
#
# [........................................] 100.00% Repairing epochs /   No bad epochs were found for your data. Returning a copy of the data you wanted to clean. Interpolation may have been done.
# Opening raw data file /storage/Yann/saflow_DATA/saflow_preproc/SA05_1_preproc_raw.fif.gz...
# /home/karim/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
#     Read 5 compensation matrices
#     Range : 0 ... 587999 =      0.000 ...   489.999 secs
# Ready.
# Current compensation grade : 3
# Reading 0 ... 587999  =      0.000 ...   489.999 secs...
# Trigger channel has a non-zero initial value of 10 (consider using initial_event=True to detect this event)
# Removing orphaned offset at the beginning of the file.
# 1175 events found
# Event IDs: [21 31 99]
# last event
# 120 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 120 events and 961 original time points ...
# 0 bad epochs dropped
# 126 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 126 events and 961 original time points ...
# 0 bad epochs dropped
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs |
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs |
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs |
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs |
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.60 and n_interpolate=32
#
# [........................................] 100.00% Repairing epochs |   No bad epochs were found for your data. Returning a copy of the data you wanted to clean. Interpolation may have been done.
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs -
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs -
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs -
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs -
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.70 and n_interpolate=32
#
# [........................................] 100.00% Repairing epochs -   No bad epochs were found for your data. Returning a copy of the data you wanted to clean. Interpolation may have been done.
# Opening raw data file /storage/Yann/saflow_DATA/saflow_preproc/SA05_2_preproc_raw.fif.gz...
# /home/karim/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
#     Read 5 compensation matrices
#     Range : 0 ... 587999 =      0.000 ...   489.999 secs
# Ready.
# Current compensation grade : 3
# Reading 0 ... 587999  =      0.000 ...   489.999 secs...
# Trigger channel has a non-zero initial value of 10 (consider using initial_event=True to detect this event)
# Removing orphaned offset at the beginning of the file.
# 1193 events found
# Event IDs: [21 31 99]
# 116 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 116 events and 961 original time points ...
# 0 bad epochs dropped
# 123 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 123 events and 961 original time points ...
# 0 bad epochs dropped
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs |
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs |
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs |
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs |
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.50 and n_interpolate=4
#
# [........................................] 100.00% Repairing epochs |   Dropped 6 epochs
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs \
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs \
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs \
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs \
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.50 and n_interpolate=32
#
# [........................................] 100.00% Repairing epochs \   Dropped 5 epochs
# Opening raw data file /storage/Yann/saflow_DATA/saflow_preproc/SA05_3_preproc_raw.fif.gz...
# /home/karim/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
#     Read 5 compensation matrices
#     Range : 0 ... 587999 =      0.000 ...   489.999 secs
# Ready.
# Current compensation grade : 3
# Reading 0 ... 587999  =      0.000 ...   489.999 secs...
# Trigger channel has a non-zero initial value of 10 (consider using initial_event=True to detect this event)
# Removing orphaned offset at the beginning of the file.
# 1249 events found
# Event IDs: [21 31 99]
# 114 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 114 events and 961 original time points ...
# 0 bad epochs dropped
# 114 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 114 events and 961 original time points ...
# 0 bad epochs dropped
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs -
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs -
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs -
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs -
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.40 and n_interpolate=32
#
# [........................................] 100.00% Repairing epochs -   Dropped 10 epochs
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs -
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs -
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs -
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs -
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.60 and n_interpolate=32
#
# [........................................] 100.00% Repairing epochs -   Dropped 3 epochs
# Opening raw data file /storage/Yann/saflow_DATA/saflow_preproc/SA05_4_preproc_raw.fif.gz...
# /home/karim/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
#     Read 5 compensation matrices
#     Range : 0 ... 587999 =      0.000 ...   489.999 secs
# Ready.
# Current compensation grade : 3
# Reading 0 ... 587999  =      0.000 ...   489.999 secs...
# Trigger channel has a non-zero initial value of 10 (consider using initial_event=True to detect this event)
# Removing orphaned offset at the beginning of the file.
# 1229 events found
# Event IDs: [21 31 99]
# 117 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 117 events and 961 original time points ...
# 0 bad epochs dropped
# 124 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 124 events and 961 original time points ...
# 0 bad epochs dropped
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs /
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs /
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs /
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs /
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.70 and n_interpolate=4
#
# [........................................] 100.00% Repairing epochs /   Dropped 3 epochs
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs |
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs |
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs |
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs |
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.50 and n_interpolate=32
#
# [........................................] 100.00% Repairing epochs |   Dropped 6 epochs
# Opening raw data file /storage/Yann/saflow_DATA/saflow_preproc/SA05_5_preproc_raw.fif.gz...
# /home/karim/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
#     Read 5 compensation matrices
#     Range : 0 ... 587999 =      0.000 ...   489.999 secs
# Ready.
# Current compensation grade : 3
# Reading 0 ... 587999  =      0.000 ...   489.999 secs...
# Trigger channel has a non-zero initial value of 10 (consider using initial_event=True to detect this event)
# Removing orphaned offset at the beginning of the file.
# 1245 events found
# Event IDs: [21 31 99]
# 114 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 114 events and 961 original time points ...
# 0 bad epochs dropped
# 111 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 111 events and 961 original time points ...
# 0 bad epochs dropped
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs -
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs -
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs -
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs -
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.60 and n_interpolate=32
#
# [........................................] 100.00% Repairing epochs -   Dropped 7 epochs
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs \
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs \
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs \
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs \
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.70 and n_interpolate=32
#
# [........................................] 100.00% Repairing epochs \   Dropped 5 epochs
# Opening raw data file /storage/Yann/saflow_DATA/saflow_preproc/SA05_6_preproc_raw.fif.gz...
# /home/karim/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
#     Read 5 compensation matrices
#     Range : 0 ... 587999 =      0.000 ...   489.999 secs
# Ready.
# Current compensation grade : 3
# Reading 0 ... 587999  =      0.000 ...   489.999 secs...
# Trigger channel has a non-zero initial value of 10 (consider using initial_event=True to detect this event)
# Removing orphaned offset at the beginning of the file.
# 1274 events found
# Event IDs: [21 31 99]
# 111 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 111 events and 961 original time points ...
# 0 bad epochs dropped
# 113 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 113 events and 961 original time points ...
# 0 bad epochs dropped
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs \
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs \
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs \
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs \
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.60 and n_interpolate=32
#
# [........................................] 100.00% Repairing epochs \   Dropped 4 epochs
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs /
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs /
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs /
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs /
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.70 and n_interpolate=32
#
# [........................................] 100.00% Repairing epochs /   Dropped 9 epochs
# Opening raw data file /storage/Yann/saflow_DATA/saflow_preproc/SA06_1_preproc_raw.fif.gz...
# /home/karim/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
#     Read 5 compensation matrices
#     Range : 0 ... 587999 =      0.000 ...   489.999 secs
# Ready.
# Current compensation grade : 3
# Reading 0 ... 587999  =      0.000 ...   489.999 secs...
# Trigger channel has a non-zero initial value of 10 (consider using initial_event=True to detect this event)
# Removing orphaned offset at the beginning of the file.
# 1312 events found
# Event IDs: [21 31 99]
# 102 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 102 events and 961 original time points ...
# 0 bad epochs dropped
# 107 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 107 events and 961 original time points ...
# 0 bad epochs dropped
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs -
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs -
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs -
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs -
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.50 and n_interpolate=4
#
# [........................................] 100.00% Repairing epochs -   Dropped 1 epoch
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs \
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs \
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs \
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs \
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.50 and n_interpolate=32
#
# [........................................] 100.00% Repairing epochs \   No bad epochs were found for your data. Returning a copy of the data you wanted to clean. Interpolation may have been done.
# Opening raw data file /storage/Yann/saflow_DATA/saflow_preproc/SA06_2_preproc_raw.fif.gz...
# /home/karim/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
#     Read 5 compensation matrices
#     Range : 0 ... 587999 =      0.000 ...   489.999 secs
# Ready.
# Current compensation grade : 3
# Reading 0 ... 587999  =      0.000 ...   489.999 secs...
# Trigger channel has a non-zero initial value of 10 (consider using initial_event=True to detect this event)
# Removing orphaned offset at the beginning of the file.
# 1193 events found
# Event IDs: [21 31 99]
# last event
# 116 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 116 events and 961 original time points ...
# 0 bad epochs dropped
# 116 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 116 events and 961 original time points ...
# 0 bad epochs dropped
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs |
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs |
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs |
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs |
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.60 and n_interpolate=32
#
# [........................................] 100.00% Repairing epochs |   No bad epochs were found for your data. Returning a copy of the data you wanted to clean. Interpolation may have been done.
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs |
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs |
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs |
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs |
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.60 and n_interpolate=4
#
# [........................................] 100.00% Repairing epochs |   No bad epochs were found for your data. Returning a copy of the data you wanted to clean. Interpolation may have been done.
# Opening raw data file /storage/Yann/saflow_DATA/saflow_preproc/SA06_3_preproc_raw.fif.gz...
# /home/karim/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
#     Read 5 compensation matrices
# ...
# Opening raw data file /storage/Yann/saflow_DATA/saflow_preproc/SA13_1_preproc_raw.fif.gz...
# /home/karim/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
#     Read 5 compensation matrices
#     Range : 0 ... 587999 =      0.000 ...   489.999 secs
# Ready.
# Current compensation grade : 3
# Reading 0 ... 587999  =      0.000 ...   489.999 secs...
# Trigger channel has a non-zero initial value of 10 (consider using initial_event=True to detect this event)
# Removing orphaned offset at the beginning of the file.
# 1151 events found
# Event IDs: [21 31 99]
# 119 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 119 events and 961 original time points ...
# 0 bad epochs dropped
# 130 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 130 events and 961 original time points ...
# 0 bad epochs dropped
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs \
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs \
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs \
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs \
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.50 and n_interpolate=4
#
# [........................................] 100.00% Repairing epochs \   Dropped 2 epochs
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs -
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs -
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs -
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs -
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.70 and n_interpolate=1
#
# [........................................] 100.00% Repairing epochs -   No bad epochs were found for your data. Returning a copy of the data you wanted to clean. Interpolation may have been done.
# Opening raw data file /storage/Yann/saflow_DATA/saflow_preproc/SA13_2_preproc_raw.fif.gz...
# /home/karim/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
#     Read 5 compensation matrices
#     Range : 0 ... 587999 =      0.000 ...   489.999 secs
# Ready.
# Current compensation grade : 3
# Reading 0 ... 587999  =      0.000 ...   489.999 secs...
# Trigger channel has a non-zero initial value of 10 (consider using initial_event=True to detect this event)
# Removing orphaned offset at the beginning of the file.
# 1160 events found
# Event IDs: [21 31 99]
# 126 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 126 events and 961 original time points ...
# 0 bad epochs dropped
# 126 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 126 events and 961 original time points ...
# 0 bad epochs dropped
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs -
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs -
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs -
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs -
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.60 and n_interpolate=1
#
# [........................................] 100.00% Repairing epochs -   Dropped 3 epochs
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs -
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs -
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs -
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs -
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.40 and n_interpolate=32
#
# [........................................] 100.00% Repairing epochs -   Dropped 12 epochs
# Opening raw data file /storage/Yann/saflow_DATA/saflow_preproc/SA13_3_preproc_raw.fif.gz...
# /home/karim/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
#     Read 5 compensation matrices
#     Range : 0 ... 587999 =      0.000 ...   489.999 secs
# Ready.
# Current compensation grade : 3
# Reading 0 ... 587999  =      0.000 ...   489.999 secs...
# Trigger channel has a non-zero initial value of 10 (consider using initial_event=True to detect this event)
# Removing orphaned offset at the beginning of the file.
# 1229 events found
# Event IDs: [21 31 99]
# last event
# 117 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 117 events and 961 original time points ...
# 0 bad epochs dropped
# 117 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 117 events and 961 original time points ...
# 0 bad epochs dropped
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs /
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs /
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs /
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs /
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.60 and n_interpolate=4
#
# [........................................] 100.00% Repairing epochs /   Dropped 3 epochs
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs /
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs /
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs /
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs /
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.90 and n_interpolate=1
#
# [........................................] 100.00% Repairing epochs /   No bad epochs were found for your data. Returning a copy of the data you wanted to clean. Interpolation may have been done.
# Opening raw data file /storage/Yann/saflow_DATA/saflow_preproc/SA13_4_preproc_raw.fif.gz...
# /home/karim/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
#     Read 5 compensation matrices
#     Range : 0 ... 587999 =      0.000 ...   489.999 secs
# Ready.
# Current compensation grade : 3
# Reading 0 ... 587999  =      0.000 ...   489.999 secs...
# Trigger channel has a non-zero initial value of 10 (consider using initial_event=True to detect this event)
# Removing orphaned offset at the beginning of the file.
# 1216 events found
# Event IDs: [21 31 99]
# 114 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 114 events and 961 original time points ...
# 0 bad epochs dropped
# 114 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# Removing 5 compensators from info because not all compensation channels were picked.
# 0 projection items activated
# Loading data for 114 events and 961 original time points ...
# 0 bad epochs dropped
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs -
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs -
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs -
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs -
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.40 and n_interpolate=32
#
# [........................................] 100.00% Repairing epochs -   Dropped 15 epochs
# 84 coil definitions read
# Running autoreject on ch_type=mag
#
# [........................................] 100.00% Creating augmented epochs -
# [........................................] 100.00% Computing thresholds ... -
# [........................................] 100.00% Repairing epochs -
# [                                        ]   0.00% n_interp |
# [........................................] 100.00% Repairing epochs -
# [.............                           ]  33.33% n_interp /
# [........................................] 100.00% Repairing epochs -
# [..........................              ]  66.67% n_interp -
# [........................................] 100.00% Repairing epochs -
# [........................................] 100.00% n_interp \
#
#
#
# Estimated consensus=0.80 and n_interpolate=4
#
# [........................................] 100.00% Repairing epochs -   No bad epochs were found for your data. Returning a copy of the data you wanted to clean. Interpolation may have been done.
# Opening raw data file /storage/Yann/saflow_DATA/saflow_preproc/SA13_5_preproc_raw.fif.gz...
# /home/karim/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
#     Read 5 compensation matrices
#     Range : 0 ... 587999 =      0.000 ...   489.999 secs
# Ready.
# Current compensation grade : 3
# Reading 0 ... 587999  =      0.000 ...   489.999 secs...
# Trigger channel has a non-zero initial value of 10 (consider using initial_event=True to detect this event)
# Removing orphaned offset at the beginning of the file.
# 1280 events found
# Event IDs: [16 21 31 99]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-0f52118667f6> in <module>
#      18
#      19         ### Find events, split them by IN/OUT and start epoching
# ---> 20         events = mne.find_events(raw)
#      21         INevents, OUTevents = split_events_by_VTC(INzone, OUTzone, events)
#      22         try:
#
# ~/electrophy/lib/python3.6/site-packages/mne/event.py in find_events(raw, stim_channel, output, consecutive, min_duration, shortest_event, mask, uint_cast, mask_type, initial_event, verbose)
#
# ~/electrophy/lib/python3.6/site-packages/mne/utils.py in verbose(function, *args, **kwargs)
#     950         with use_log_level(verbose_level):
#     951             return function(*args, **kwargs)
# --> 952     return function(*args, **kwargs)
#     953
#     954
#
# ~/electrophy/lib/python3.6/site-packages/mne/event.py in find_events(raw, stim_channel, output, consecutive, min_duration, shortest_event, mask, uint_cast, mask_type, initial_event, verbose)
#     705                              "e.g. x / raw.info['sfreq']. Where x = 1 sample "
#     706                              "shorter than the shortest event "
# --> 707                              "length." % (n_short_events))
#     708
#     709         events_list.append(events)
#
# ValueError: You have 1 events shorter than the shortest_event. These are very unusual and you may want to set min_duration to a larger value e.g. x / raw.info['sfreq']. Where x = 1 sample shorter than the shortest event length.

# %%
#### Debug shortest event in find_events


subj = '13'
bloc = 5
preproc_file = find_preprocfile(subj, bloc, os.listdir(PREPROC_PATH))
raw = read_raw_fif(PREPROC_PATH + preproc_file, preload=True)
picks = mne.pick_types(raw.info, meg=True, ref_meg=False, eeg=False, eog=False, stim=False)

### Set some constants for epoching

baseline = (None, 0.0)
reject = {'mag': 4e-12}
tmin, tmax = 0, 0.8

### Find events, split them by IN/OUT and start epoching
events = mne.find_events(raw, min_duration=2/raw.info['sfreq'])
# Out:
# Opening raw data file /storage/Yann/saflow_DATA/saflow_preproc/SA13_5_preproc_raw.fif.gz...
#     Read 5 compensation matrices
#     Range : 0 ... 587999 =      0.000 ...   489.999 secs
# Ready.
# Current compensation grade : 3
# Reading 0 ... 587999  =      0.000 ...   489.999 secs...
# Trigger channel has a non-zero initial value of 10 (consider using initial_event=True to detect this event)
# Removing orphaned offset at the beginning of the file.
# 1280 events found
# Event IDs: [16 21 31 99]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-31bbfe5e9e7c> in <module>
#      15
#      16 ### Find events, split them by IN/OUT and start epoching
# ---> 17 events = mne.find_events(raw, min_duration=1/raw.info['sfreq'])
#      18
#      19
#
# ~/electrophy/lib/python3.6/site-packages/mne/event.py in find_events(raw, stim_channel, output, consecutive, min_duration, shortest_event, mask, uint_cast, mask_type, initial_event, verbose)
#
# ~/electrophy/lib/python3.6/site-packages/mne/utils.py in verbose(function, *args, **kwargs)
#     950         with use_log_level(verbose_level):
#     951             return function(*args, **kwargs)
# --> 952     return function(*args, **kwargs)
#     953
#     954
#
# ~/electrophy/lib/python3.6/site-packages/mne/event.py in find_events(raw, stim_channel, output, consecutive, min_duration, shortest_event, mask, uint_cast, mask_type, initial_event, verbose)
#     705                              "e.g. x / raw.info['sfreq']. Where x = 1 sample "
#     706                              "shorter than the shortest event "
# --> 707                              "length." % (n_short_events))
#     708
#     709         events_list.append(events)
#
# ValueError: You have 1 events shorter than the shortest_event. These are very unusual and you may want to set min_duration to a larger value e.g. x / raw.info['sfreq']. Where x = 1 sample shorter than the shortest event length.

# %%
### OPEN SEGMENTED FILES AND COMPUTE PSDS

for subj in subj_list:
    for bloc in blocs_list:
        for zone in ['IN', 'OUT']:
            data = mne.read_epochs(EPOCHS_DIR + 'SA' + subj + '_' + bloc + '_' + zone + '_epo.fif.gz')
            psds = compute_PSD(data, data.info['sfreq'], epochs_length = 0.8)
            psds = np.mean(psds, axis=2)
            for i, freq_name in enumerate(FREQS_NAMES):
                PSD_save = psds[i]
                savemat(PSDS_DIR + 'SA' + subj + '_' + bloc + '_' + zone + '_' + freq_name + '.mat', {'PSD': PSD_save})
# Out:
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA04_1_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 108 matching events found
# Applying baseline correction (mode: mean)
# 108 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# /home/karim/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/signal/signaltools.py:1344: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# /home/karim/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/signal/signaltools.py:1593: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   h = h[ind]
# /home/karim/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/signal/signaltools.py:1341: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out_full[ind] += zi
# /home/karim/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/signal/signaltools.py:1350: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   zf = out_full[ind]
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA04_1_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 106 matching events found
# Applying baseline correction (mode: mean)
# 106 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA04_2_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 96 matching events found
# Applying baseline correction (mode: mean)
# 96 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA04_2_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 103 matching events found
# Applying baseline correction (mode: mean)
# 103 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA04_3_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 106 matching events found
# Applying baseline correction (mode: mean)
# 106 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA04_3_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 109 matching events found
# Applying baseline correction (mode: mean)
# 109 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA04_4_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 108 matching events found
# Applying baseline correction (mode: mean)
# 108 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA04_4_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 97 matching events found
# Applying baseline correction (mode: mean)
# 97 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA04_5_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 110 matching events found
# Applying baseline correction (mode: mean)
# 110 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA04_5_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 121 matching events found
# Applying baseline correction (mode: mean)
# 121 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA04_6_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 98 matching events found
# Applying baseline correction (mode: mean)
# 98 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA04_6_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 101 matching events found
# Applying baseline correction (mode: mean)
# 101 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA05_1_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 120 matching events found
# Applying baseline correction (mode: mean)
# 120 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA05_1_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 126 matching events found
# Applying baseline correction (mode: mean)
# 126 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA05_2_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 110 matching events found
# Applying baseline correction (mode: mean)
# 110 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA05_2_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 118 matching events found
# Applying baseline correction (mode: mean)
# 118 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA05_3_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 104 matching events found
# Applying baseline correction (mode: mean)
# 104 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA05_3_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 111 matching events found
# Applying baseline correction (mode: mean)
# 111 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA05_4_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 114 matching events found
# Applying baseline correction (mode: mean)
# 114 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA05_4_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 118 matching events found
# Applying baseline correction (mode: mean)
# 118 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA05_5_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 107 matching events found
# Applying baseline correction (mode: mean)
# 107 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA05_5_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 106 matching events found
# Applying baseline correction (mode: mean)
# 106 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA05_6_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 107 matching events found
# Applying baseline correction (mode: mean)
# 107 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA05_6_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 104 matching events found
# Applying baseline correction (mode: mean)
# 104 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA06_1_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 101 matching events found
# Applying baseline correction (mode: mean)
# 101 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA06_1_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 107 matching events found
# Applying baseline correction (mode: mean)
# 107 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA06_2_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 116 matching events found
# Applying baseline correction (mode: mean)
# 116 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA06_2_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 116 matching events found
# Applying baseline correction (mode: mean)
# 116 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA06_3_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 118 matching events found
# Applying baseline correction (mode: mean)
# 118 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA06_3_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 109 matching events found
# Applying baseline correction (mode: mean)
# 109 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA06_4_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 97 matching events found
# Applying baseline correction (mode: mean)
# 97 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA06_4_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 109 matching events found
# Applying baseline correction (mode: mean)
# 109 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA06_5_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 106 matching events found
# Applying baseline correction (mode: mean)
# 106 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA06_5_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 121 matching events found
# Applying baseline correction (mode: mean)
# 121 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA06_6_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 103 matching events found
# Applying baseline correction (mode: mean)
# 103 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA06_6_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 107 matching events found
# Applying baseline correction (mode: mean)
# 107 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA07_1_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 112 matching events found
# Applying baseline correction (mode: mean)
# 112 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA07_1_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 108 matching events found
# Applying baseline correction (mode: mean)
# 108 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA07_2_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 110 matching events found
# Applying baseline correction (mode: mean)
# 110 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA07_2_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 126 matching events found
# Applying baseline correction (mode: mean)
# 126 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA07_3_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 122 matching events found
# Applying baseline correction (mode: mean)
# 122 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA07_3_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 115 matching events found
# Applying baseline correction (mode: mean)
# 115 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA07_4_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 111 matching events found
# Applying baseline correction (mode: mean)
# 111 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA07_4_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 119 matching events found
# Applying baseline correction (mode: mean)
# 119 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA07_5_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 115 matching events found
# Applying baseline correction (mode: mean)
# 115 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA07_5_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 128 matching events found
# Applying baseline correction (mode: mean)
# 128 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA07_6_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 116 matching events found
# Applying baseline correction (mode: mean)
# 116 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA07_6_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 110 matching events found
# Applying baseline correction (mode: mean)
# 110 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA08_1_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 105 matching events found
# Applying baseline correction (mode: mean)
# 105 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA08_1_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 106 matching events found
# Applying baseline correction (mode: mean)
# 106 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA08_2_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 97 matching events found
# Applying baseline correction (mode: mean)
# 97 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA08_2_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 102 matching events found
# Applying baseline correction (mode: mean)
# 102 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA08_3_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 105 matching events found
# Applying baseline correction (mode: mean)
# 105 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA08_3_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 103 matching events found
# Applying baseline correction (mode: mean)
# 103 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA08_4_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 114 matching events found
# Applying baseline correction (mode: mean)
# 114 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA08_4_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 117 matching events found
# Applying baseline correction (mode: mean)
# 117 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA08_5_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 116 matching events found
# Applying baseline correction (mode: mean)
# 116 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA08_5_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 118 matching events found
# Applying baseline correction (mode: mean)
# 118 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA08_6_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 109 matching events found
# Applying baseline correction (mode: mean)
# 109 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA08_6_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 109 matching events found
# Applying baseline correction (mode: mean)
# 109 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA09_1_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 110 matching events found
# Applying baseline correction (mode: mean)
# 110 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA09_1_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 120 matching events found
# Applying baseline correction (mode: mean)
# 120 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA09_2_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 111 matching events found
# Applying baseline correction (mode: mean)
# 111 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA09_2_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 121 matching events found
# Applying baseline correction (mode: mean)
# 121 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA09_3_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 122 matching events found
# Applying baseline correction (mode: mean)
# 122 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA09_3_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 124 matching events found
# Applying baseline correction (mode: mean)
# 124 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA09_4_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 117 matching events found
# Applying baseline correction (mode: mean)
# 117 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA09_4_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 112 matching events found
# Applying baseline correction (mode: mean)
# 112 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA09_5_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 121 matching events found
# Applying baseline correction (mode: mean)
# 121 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA09_5_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 113 matching events found
# Applying baseline correction (mode: mean)
# 113 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA09_6_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 119 matching events found
# Applying baseline correction (mode: mean)
# 119 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA09_6_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 122 matching events found
# Applying baseline correction (mode: mean)
# 122 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA10_1_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 110 matching events found
# Applying baseline correction (mode: mean)
# 110 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA10_1_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 108 matching events found
# Applying baseline correction (mode: mean)
# 108 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA10_2_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 111 matching events found
# Applying baseline correction (mode: mean)
# 111 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA10_2_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 112 matching events found
# Applying baseline correction (mode: mean)
# 112 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA10_3_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 120 matching events found
# Applying baseline correction (mode: mean)
# 120 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA10_3_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 116 matching events found
# Applying baseline correction (mode: mean)
# 116 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA10_4_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 127 matching events found
# Applying baseline correction (mode: mean)
# 127 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA10_4_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 126 matching events found
# Applying baseline correction (mode: mean)
# 126 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA10_5_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 118 matching events found
# Applying baseline correction (mode: mean)
# 118 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA10_5_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 119 matching events found
# Applying baseline correction (mode: mean)
# 119 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA10_6_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 118 matching events found
# Applying baseline correction (mode: mean)
# 118 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA10_6_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 122 matching events found
# Applying baseline correction (mode: mean)
# 122 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA11_1_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 112 matching events found
# Applying baseline correction (mode: mean)
# 112 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA11_1_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 112 matching events found
# Applying baseline correction (mode: mean)
# 112 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA11_2_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 105 matching events found
# Applying baseline correction (mode: mean)
# 105 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA11_2_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 101 matching events found
# Applying baseline correction (mode: mean)
# 101 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA11_3_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 103 matching events found
# Applying baseline correction (mode: mean)
# 103 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA11_3_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 110 matching events found
# Applying baseline correction (mode: mean)
# 110 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA11_4_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 111 matching events found
# Applying baseline correction (mode: mean)
# 111 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA11_4_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 103 matching events found
# Applying baseline correction (mode: mean)
# 103 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA11_5_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 106 matching events found
# Applying baseline correction (mode: mean)
# 106 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA11_5_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 109 matching events found
# Applying baseline correction (mode: mean)
# 109 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA11_6_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 112 matching events found
# Applying baseline correction (mode: mean)
# 112 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA11_6_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 114 matching events found
# Applying baseline correction (mode: mean)
# 114 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA12_1_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 108 matching events found
# Applying baseline correction (mode: mean)
# 108 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA12_1_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 108 matching events found
# Applying baseline correction (mode: mean)
# 108 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA12_2_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 112 matching events found
# Applying baseline correction (mode: mean)
# 112 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA12_2_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 115 matching events found
# Applying baseline correction (mode: mean)
# 115 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA12_3_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 112 matching events found
# Applying baseline correction (mode: mean)
# 112 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA12_3_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 100 matching events found
# Applying baseline correction (mode: mean)
# 100 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA12_4_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 109 matching events found
# Applying baseline correction (mode: mean)
# 109 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA12_4_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 108 matching events found
# Applying baseline correction (mode: mean)
# 108 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA12_5_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 115 matching events found
# Applying baseline correction (mode: mean)
# 115 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA12_5_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 118 matching events found
# Applying baseline correction (mode: mean)
# 118 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA12_6_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 94 matching events found
# Applying baseline correction (mode: mean)
# 94 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA12_6_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 105 matching events found
# Applying baseline correction (mode: mean)
# 105 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA13_1_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 117 matching events found
# Applying baseline correction (mode: mean)
# 117 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA13_1_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 130 matching events found
# Applying baseline correction (mode: mean)
# 130 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA13_2_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 123 matching events found
# Applying baseline correction (mode: mean)
# 123 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA13_2_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 114 matching events found
# Applying baseline correction (mode: mean)
# 114 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA13_3_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 114 matching events found
# Applying baseline correction (mode: mean)
# 114 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA13_3_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 117 matching events found
# Applying baseline correction (mode: mean)
# 117 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA13_4_IN_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 99 matching events found
# Applying baseline correction (mode: mean)
# 99 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA13_4_OUT_epo.fif.gz ...
#     Found the data of interest:
#         t =       0.00 ...     800.00 ms
#         0 CTF compensation matrices available
# 114 matching events found
# Applying baseline correction (mode: mean)
# 114 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Reading /storage/Yann/saflow_DATA/saflow_epoched/SA13_5_IN_epo.fif.gz ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-a15b4f91c5c7> in <module>
#       4     for bloc in blocs_list:
#       5         for zone in ['IN', 'OUT']:
# ----> 6             data = mne.read_epochs(EPOCHS_DIR + 'SA' + subj + '_' + bloc + '_' + zone + '_epo.fif.gz')
#       7             psds = compute_PSD(data, data.info['sfreq'], epochs_length = 0.8)
#       8             psds = np.mean(psds, axis=2)
#
# ~/electrophy/lib/python3.6/site-packages/mne/epochs.py in read_epochs(fname, proj, preload, verbose)
#
# ~/electrophy/lib/python3.6/site-packages/mne/utils.py in verbose(function, *args, **kwargs)
#     950         with use_log_level(verbose_level):
#     951             return function(*args, **kwargs)
# --> 952     return function(*args, **kwargs)
#     953
#     954
#
# ~/electrophy/lib/python3.6/site-packages/mne/epochs.py in read_epochs(fname, proj, preload, verbose)
#    2700         The epochs
#    2701     """
# -> 2702     return EpochsFIF(fname, proj, preload, verbose)
#    2703
#    2704
#
# ~/electrophy/lib/python3.6/site-packages/mne/epochs.py in __init__(self, fname, proj, preload, verbose)
#
# ~/electrophy/lib/python3.6/site-packages/mne/utils.py in verbose(function, *args, **kwargs)
#     950         with use_log_level(verbose_level):
#     951             return function(*args, **kwargs)
# --> 952     return function(*args, **kwargs)
#     953
#     954
#
# ~/electrophy/lib/python3.6/site-packages/mne/epochs.py in __init__(self, fname, proj, preload, verbose)
#    2762         for fname in fnames:
#    2763             logger.info('Reading %s ...' % fname)
# -> 2764             fid, tree, _ = fiff_open(fname)
#    2765             next_fname = _get_next_fname(fid, fname, tree)
#    2766             (info, data, data_tag, events, event_id, metadata, tmin, tmax,
#
# ~/electrophy/lib/python3.6/site-packages/mne/io/open.py in fiff_open(fname, preload, verbose)
#
# ~/electrophy/lib/python3.6/site-packages/mne/utils.py in verbose(function, *args, **kwargs)
#     950         with use_log_level(verbose_level):
#     951             return function(*args, **kwargs)
# --> 952     return function(*args, **kwargs)
#     953
#     954
#
# ~/electrophy/lib/python3.6/site-packages/mne/io/open.py in fiff_open(fname, preload, verbose)
#     101         A list of tags.
#     102     """
# --> 103     fid = _fiff_get_fid(fname)
#     104     # do preloading of entire file
#     105     if preload:
#
# ~/electrophy/lib/python3.6/site-packages/mne/io/open.py in _fiff_get_fid(fname)
#      24         if op.splitext(fname)[1].lower() == '.gz':
#      25             logger.debug('Using gzip')
# ---> 26             fid = GzipFile(fname, "rb")  # Open in binary mode
#      27         else:
#      28             logger.debug('Using normal I/O')
#
# /usr/lib/python3.6/gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     161             mode += 'b'
#     162         if fileobj is None:
# --> 163             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     164         if filename is None:
#     165             filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/storage/Yann/saflow_DATA/saflow_epoched/SA13_5_IN_epo.fif.gz'

# %%
### OPEN PSDS AND CREATE TOPOPLOTS

#### ALL SUBJ TOPOPLOT

# create a pdf with psd topoplots
ch_file = '/home/karim/pCloudDrive/science/saflow/DATAmeg_gradCPT/20190411/SA04_SAflow-yharel_20190411_02.ds'
raw = mne.io.read_raw_ctf(ch_file)
ch_xy = get_ch_pos(raw)

toplot = []
for i, freq_name in enumerate(FREQS_NAMES):
    alldata = []
    for zone in ['IN', 'OUT']:
        zonedata = []
        for subj in subj_list:
            subjdata = []
            for bloc in blocs_list:
                mat = loadmat(PSDS_DIR + 'SA' + subj + '_' + bloc + '_' + zone + '_' + freq_name + '.mat')
                data = mat['PSD']
                if subjdata == []:
                    subjdata = data
                else:
                    subjdata = np.hstack((subjdata, data))
            subjdata = np.mean(subjdata, axis=1) # average blocs
            zonedata.append(subjdata)
        alldata.append(np.asarray(zonedata))
    alldata = np.asarray(alldata)
    alldata = np.mean(alldata, axis=1) # average subjects
    toplot.append((alldata[0] - alldata[1])/alldata[1])
array_topoplot(toplot, ch_xy, showtitle=True, titles=FREQS_NAMES, savefig=True, figpath=IMG_DIR + 'IN_vs_OUT_PSD_autoreject_4subj.png', vmin=np.min(np.min(toplot)), vmax=np.max(np.max(toplot)))
    #array_topoplot(alldata[1], ch_xy, showtitle=False, titles=None, savefig=False, figpath=None, vmin=-1, vmax=1)

    #print(alldata[1])
# Out:
# ds directory : /home/karim/pCloudDrive/science/saflow/DATAmeg_gradCPT/20190411/SA04_SAflow-yharel_20190411_02.ds
#     res4 data read.
#     hc data read.
#     Separate EEG position data file read.
#     Quaternion matching (desired vs. transformed):
#        1.74   79.24    0.00 mm <->    1.74   79.24   -0.00 mm (orig :  -67.36   48.31 -242.66 mm) diff =    0.000 mm
#       -1.74  -79.24    0.00 mm <->   -1.74  -79.24    0.00 mm (orig :   43.50  -64.96 -245.83 mm) diff =    0.000 mm
#      114.47    0.00    0.00 mm <->  114.46   -0.00   -0.00 mm (orig :   67.74   73.41 -252.87 mm) diff =    0.000 mm
#     Coordinate transformations established.
#     Polhemus data for 3 HPI coils added
#     Device coordinate locations for 3 HPI coils added
#     Measurement info composed.
# Finding samples for /home/karim/pCloudDrive/science/saflow/DATAmeg_gradCPT/20190411/SA04_SAflow-yharel_20190411_02.ds/SA04_SAflow-yharel_20190411_02.meg4:
#     System clock channel is available, checking which samples are valid.
#     1 x 588000 = 588000 samples from 334 chs
# Current compensation grade : 3
# /home/karim/electrophy/lib/python3.6/site-packages/ipykernel_launcher.py:20: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/io/matlab/mio.py in _open_file(file_like, appendmat)
#      32     try:
# ---> 33         return open(file_like, 'rb'), True
#      34     except IOError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/storage/Yann/saflow_DATA/saflow_PSD/SA13_5_IN_theta.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-e0df26e91bfc> in <module>
#      16             subjdata = []
#      17             for bloc in blocs_list:
# ---> 18                 mat = loadmat(PSDS_DIR + 'SA' + subj + '_' + bloc + '_' + zone + '_' + freq_name + '.mat')
#      19                 data = mat['PSD']
#      20                 if subjdata == []:
#
# ~/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/io/matlab/mio.py in loadmat(file_name, mdict, appendmat, **kwargs)
#     139     """
#     140     variable_names = kwargs.pop('variable_names', None)
# --> 141     MR, file_opened = mat_reader_factory(file_name, appendmat, **kwargs)
#     142     matfile_dict = MR.get_variables(variable_names)
#     143     if mdict is not None:
#
# ~/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/io/matlab/mio.py in mat_reader_factory(file_name, appendmat, **kwargs)
#      62
#      63     """
# ---> 64     byte_stream, file_opened = _open_file(file_name, appendmat)
#      65     mjv, mnv = get_matfile_version(byte_stream)
#      66     if mjv == 0:
#
# ~/electrophy/lib/python3.6/site-packages/scipy-1.1.0-py3.6-linux-x86_64.egg/scipy/io/matlab/mio.py in _open_file(file_like, appendmat)
#      37             if appendmat and not file_like.endswith('.mat'):
#      38                 file_like += '.mat'
# ---> 39             return open(file_like, 'rb'), True
#      40         else:
#      41             raise IOError('Reader needs file name or open file-like object')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/storage/Yann/saflow_DATA/saflow_PSD/SA13_5_IN_theta.mat'

# %%
### OPEN PSDS AND CREATE TOPOPLOTS

#### INDIVIDUAL SUBJ TOPOPLOT

# create a pdf with psd topoplots
ch_file = '/home/karim/pCloudDrive/science/saflow/DATAmeg_gradCPT/20190411/SA04_SAflow-yharel_20190411_02.ds'
raw = mne.io.read_raw_ctf(ch_file)
ch_xy = get_ch_pos(raw)

toplot = []
for i, freq_name in enumerate(FREQS_NAMES):
    alldata = []
    for zone in ['IN', 'OUT']:
        zonedata = []
        for subj in subj_list:
            subjdata = []
            for bloc in blocs_list:
                mat = loadmat(PSDS_DIR + 'SA' + subj + '_' + bloc + '_' + zone + '_' + freq_name + '.mat')
                data = mat['PSD']
                if subjdata == []:
                    subjdata = data
                else:
                    subjdata = np.hstack((subjdata, data))
            subjdata = np.mean(subjdata, axis=1) # average blocs
            zonedata.append(subjdata)
        alldata.append(np.asarray(zonedata))
    #alldata = np.mean(np.asarray(alldata), axis=1) # average subjects
    alldata = np.asarray(alldata)
    toplot.append((alldata[0] - alldata[1])/alldata[1])
toplot = np.asarray(toplot)

for i, subj in enumerate(subj_list):
    print(subj)
    array_topoplot(toplot[:,i,:], ch_xy, showtitle=True, titles=FREQS_NAMES, savefig=True, figpath=IMG_DIR + 'IN_vs_OUT_PSD' + '_SA' + subj + '_NOar.png', vmin=np.min(np.min(toplot)), vmax=np.max(np.max(toplot)))
    #array_topoplot(alldata[1], ch_xy, showtitle=False, titles=None, savefig=False, figpath=None, vmin=-1, vmax=1)

    #print(alldata[1])

# %%
### ML single subject classification of IN vs OUT epochs
# - single-features
# - CV k-fold (maybe 10 ?)
# - LDA, RF, kNN ?
for subj in subj_list:
    all_freq_data = []
    for i, freq_name in enumerate(FREQS_NAMES):
        zonedata = []
        y = np.array([])
        for zone in ['IN', 'OUT']:
            blocdata = []
            for bloc in blocs_list:
                mat = loadmat(PSDS_DIR + 'SA' + subj + '_' + bloc + '_' + zone + '_' + freq_name + '.mat')
                data = mat['PSD']
                if blocdata == []:
                    blocdata = data
                else:
                    blocdata = np.hstack((blocdata, data))
            vstackif zone == 'IN':
                y = np.vstack((y, np.ones((blocdata.shape[1],1)))) ### 1 = IN
            else:
                y = np.vstack((y, np.zeros((blocdata.shape[1],1))))### 0 = OUT
            print(y.shape)
            
            if zonedata == []:
                zonedata = blocdata
            else:
                zonedata = np.hstack((zonedata, blocdata))
        if all_freq_data == []:
            all_freq_data = zonedata
        else:
            all_freq_data = np.vstack((all_freq_data, zonedata))
    print('SA' + subj)
    print(all_freq_data.shape)
                
                    
#### Résultat on veut : elec * freq X trials(IN+OUT) = 1890 X N_trials_tot

# %%
alldata_allfreqs = []
for i, freq_name in enumerate(FREQS_NAMES):
    alldata = []
    for zone in ['IN', 'OUT']:
        zonedata = []
        for subj in subj_list:
            subjdata = []
            for bloc in blocs_list:
                mat = loadmat(PSDS_DIR + 'SA' + subj + '_' + bloc + '_' + zone + '_' + freq_name + '.mat')
                data = mat['PSD']
                if subjdata == []:
                    subjdata = data
                else:
                    subjdata = np.hstack((subjdata, data))
            zonedata.append(subjdata)
        alldata.append(zonedata)
    alldata_allfreqs.append(alldata) ### First dimension is freq_band, second is IN/OUT, third is subject, fourth is elec X trials matrix

# %%
### Objectif : 
# get one epoched file for freq and rare AND RESP for each subj
# PLOT TOPO DE L'AMPLITUDE À ENVIRON 150MS APRES RESP
# COMPARER BLOC RESP GAUCHE AVEC BLOC RESP DROIT

##### POUR MIKE : implémenter calcul de la VTC sur Python, à partir du fichier de log


#for file in file_list:
file = file_list[-2]


fname = preproc_path + file
subj = file[:4]
bloc = file[6]

raw = read_raw_fif(fname, preload=True)
picks = mne.pick_types(raw.info, meg=True, ref_meg=False, eeg=False, eog=False, stim=False)

# %%
log_files = os.listdir(LOGS_DIR)

file = find_logfile(subj,bloc,log_files)
VTC, INbounds, OUTbounds, INzone, OUTzone = get_VTC_from_file(LOGS_DIR + file, lobound=0.25, hibound=0.75)

INbounds

# %%
events = mne.find_events(raw)
event_id = {'Freq': 21, 'Rare': 31}
color = {21: 'green', 31: 'yellow'}
mne.viz.plot_events(OUTevents, raw.info['sfreq'], raw.first_samp, color=color,
                    event_id=event_id);

# %%
a = []
a = np.array(a)
b = np.zeros((5,0))
c = np.hstack((a,b))
c

# %%
ep = read_raw_fif('/home/karim/DATA/MEG_gradCPT/saflow_epoched/SA04_1_IN.fif')

# %%
INevoked_freq = INepochs['Freq'].average()
INevoked_rare = INepochs['Rare'].average()
OUTevoked_freq = OUTepochs['Freq'].average()
OUTevoked_rare = OUTepochs['Rare'].average()

# %%
a = 1

if a >> 1:
    print('lol')
else:
    print('nana')

# %%
times = np.arange(0.1, 0.801, 0.1)
OUTepochs['Rare'].average().plot_topomap(times=times, time_unit='s', title='Rare');
plt.savefig(IMG_DIR + 'evoked_topo_OUTrare.png', dpi=800)

# %%
OUTepochs['Freq'].average().plot_topomap(times=times, time_unit='s', title='Frequent');
plt.savefig(IMG_DIR + 'evoked_topo_OUTfreq.png', dpi=800)

# %%
ar = AutoReject()
INepochs_clean = ar.fit_transform(INepochs)

# %%
### Faire une fonction qui prend un bloc, va chercher le fichier de log associé, calcule la VTC et les IN/OUT bounds
### segmente le fichier et sépare les epochs dans deux fichiers en fonction de la condition de chaque epoch

INepochs_clean.average().plot_topomap(times=times, time_unit='s');
